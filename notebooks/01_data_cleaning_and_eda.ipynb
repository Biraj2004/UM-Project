# %% [markdown]
# # Step 1: Data Cleaning, Geospatial Enrichment & Exploratory Data Analysis
# ### Nassau Candy Factory Reallocation & Shipping Optimization
# *Unified Mentor Machine Learning Internship*
#
# **Objective**: Ingest the raw transactional dataset, compute Haversine transit distances from all 5 factories, calculate lead times, and explore distribution patterns.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(".."))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_pipeline import load_raw_data, enrich_dataset

# Load and enrich raw data
raw_df = load_raw_data("../docs/Dataset - Nassau Candy Distributor.csv")
df = enrich_dataset(raw_df)
df.head()

# %% [markdown]
# ## Summary Statistics and Suboptimal Shipment Analysis

# %%
print("Total records:", len(df))
print("Average transit distance:", round(df["Transit Distance (Miles)"].mean(), 1), "miles")
print("Optimal transit distance:", round(df["Minimum Distance (Miles)"].mean(), 1), "miles")
subopt_count = df["Is Closer Factory Available"].sum()
subopt_pct = df["Is Closer Factory Available"].mean() * 100
print(f"Suboptimal shipments: {subopt_count} ({subopt_pct:.1f}%)")
