# %% [markdown]
# # Step 3: Predictive Lead Time Machine Learning Models
# ### Nassau Candy Factory Reallocation & Shipping Optimization
#
# **Objective**: Train and benchmark Linear Regression, Decision Tree, Random Forest, and Gradient Boosting Regressors for lead time prediction.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(".."))

import pandas as pd
from src.model_engine import load_dataset, prepare_features, train_and_evaluate_models

df = load_dataset("../data/processed/nassau_candy_enriched.csv")
X, y, cat_cols, num_cols = prepare_features(df)
results_df, best_model, best_name = train_and_evaluate_models(X, y, cat_cols, num_cols)
results_df
